# %%
import import_ipynb
import distance 
import data 
import Protonet
import train_and_test
import torch.optim as optim
import matplotlib.pyplot as plt
import os
# Out:
# importing Jupyter notebook from distance.ipynb
# importing Jupyter notebook from data.ipynb
# importing Jupyter notebook from Protonet.ipynb
# importing Jupyter notebook from train_and_test.ipynb

# %% [markdown]
# # PREPARE DATA

# %%
# %%time 
trainx, trainy = data.read_images('../Licheni')
testx, testy = data.read_images('../lich')
# Out:
# ../Licheni/OTHER_1/Lecanora_symmicta/TSB006238.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Lecanora_symmicta/TSB000128.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Hypotrachyna_revoluta/TSB010458.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Hypotrachyna_revoluta/TSB000098.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Hypotrachyna_revoluta/TSB010455.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Flavopunctelia_flaventior/TSB010295.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Leprocaulon_quisquiliare/TSB000591.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Enchylium_conglomeratum/TSB003750.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Enchylium_conglomeratum/TSB003754.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Enchylium_conglomeratum/TSB004179.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Anaptychia_ciliaris/TSB003268.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Anaptychia_ciliaris/TSB000260.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Normandina_pulchella/TSB004900.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Hypocenomyce_scalaris/HypocenomycescalarisAchMChoisy1543758708.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Hypocenomyce_scalaris/TSB004215.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Hypocenomyce_scalaris/HypocenomycescalarisAchMChoisy1543758701.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Myriolecis_hagenii/TSB007795.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Collema_subnigrescens/TSB004194.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Collema_subnigrescens/TSB003935.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_haematites/TSB001114.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_haematites/TSB011271.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_obscurella/TSB003917.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Collema_subflaccidum/TSB007408.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Collema_subflaccidum/TSB003756.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_ulcerosa/CaloplacaulcerosaCoppinsPJames1542632041.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_ulcerosa/CaloplacaulcerosaCoppinsPJames1542632047.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_ulcerosa/TSB004096.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_ulcerosa/TSB003924.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Caloplaca_ulcerosa/TSB003925.jpg
# (500, 500, 3)
# ../Licheni/OTHER_1/Diplotomma_alboatrum/TSB001137.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Collema_nigrescens/TSB003928.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Collema_nigrescens/CollemanigrescensHudsDC1574977114.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Collema_nigrescens/TSB003930.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Collema_nigrescens/TSB003931.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Flavoparmelia_caperata/TSB010274.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Evernia_prunastri/TSB008937.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Evernia_prunastri/TSB003331.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Evernia_prunastri/TSB005494.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Evernia_prunastri/TSB005921.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Evernia_prunastri/TSB004829.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Candelariella_xanthostigma/TSB003744.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Candelariella_xanthostigma/TSB008763.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Candelariella_xanthostigma/TSB008762.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Lecanora_expallens/TSB014072.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Lecanora_expallens/TSB014067.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Lecanora_expallens/TSB014075.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Hypogymnia_physodes/TSB007118.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Hypogymnia_physodes/TSB000100.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Hypogymnia_physodes/HypogymniaphysodesLNyl1543407690.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Blastenia_herbidella/TSB002776.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Candelariella_vie-lactae/TSB006184.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Arthonia_radiata/TSB003903.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Arthonia_radiata/TSB002259.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Hypogymnia_tubulosa/TSB005680.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Hypogymnia_tubulosa/TSB006055.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Hypogymnia_tubulosa/TSB006056.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Lecanora_chlarotera/TSB008755.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Lecanora_chlarotera/TSB003728.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Lecanora_chlarotera/TSB014043.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Blastenia_ferruginea/TSB006172.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Heterodermia_obscurata/TSB009967.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Heterodermia_obscurata/TSB001147.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Heterodermia_obscurata/TSB001146.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Heterodermia_obscurata/TSB004211.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Heterodermia_obscurata/TSB009968.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Diploicia_canescens/DiploiciacanescensDicksAMassal1543232835.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Diploicia_canescens/TSB008475.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Diploicia_canescens/TSB004202.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/Diploicia_canescens/TSB003826.jpg
# (500, 500, 3)
# ../Licheni/VIP_1/
# ../lich/super/Physcia_stellaris/TSB001225.jpg
# (500, 500, 3)
# ../lich/super/Candelariella_reflexa/TSB004127.jpg
# (500, 500, 3)
# ../lich/super/Candelariella_reflexa/TSB004126.jpg
# (500, 500, 3)
# ../lich/super/Amandinea_punctata/TSB004075.jpg
# (500, 500, 3)
# ../lich/super/Lecidella_elaeochroma/TSB003723.jpg
# (500, 500, 3)
# ../lich/super/Lecidella_elaeochroma/TSB008760.jpg
# (500, 500, 3)
# ../lich/super/Lecidella_elaeochroma/TSB008929.jpg
# (500, 500, 3)
# ../lich/super/Chrysothrix_candelaris/TSB001124.jpg
# (500, 500, 3)
# ../lich/super/Chrysothrix_candelaris/TSB018563.jpg
# (500, 500, 3)
# ../lich/super/Chrysothrix_candelaris/ChrysothrixcandelarisLJRLaundon1543331781.jpg
# (500, 500, 3)
# ../lich/super/Chrysothrix_candelaris/ChrysothrixcandelarisLJRLaundon1543331791.jpg
# (500, 500, 3)
# ../lich/super/Flavoparmelia_caperata/TSB010274.jpg
# (500, 500, 3)
# ../lich/super/Physcia_adscendens/PhysciaadscendensHOlivier1542711215.jpg
# (500, 500, 3)
# ../lich/super/Physcia_adscendens/TSB008342.jpg
# (500, 500, 3)
# ../lich/super/Physcia_adscendens/TSB003415.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/TSB004933.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/TSB005686.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/PhysciaaipoliaHumbFrnr1540829660.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/TSB008548.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/TSB008547.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/TSB004057.jpg
# (500, 500, 3)
# ../lich/super/Physcia_aipolia/PhysciaaipoliaHumbFrnr1540829593.jpg
# (500, 500, 3)
# ../lich/super/Phaeophyscia_orbicularis/TSB003692.jpg
# (500, 500, 3)
# ../lich/super/Phaeophyscia_orbicularis/PhaeophysciaorbicularisNeckMoberg1540828490.jpg
# (500, 500, 3)
# ../lich/super/Phaeophyscia_orbicularis/TSB004839.jpg
# (500, 500, 3)
# ../lich/super/Phaeophyscia_orbicularis/TSB008335.jpg
# (500, 500, 3)
# ../lich/super/Phaeophyscia_orbicularis/PhaeophysciaorbicularisNeckMoberg1542649994.jpg
# (500, 500, 3)
# ../lich/super/Physcia_biziana/TSB008267.jpg
# (500, 500, 3)
# ../lich/super/Physcia_biziana/TSB003696.jpg
# (500, 500, 3)
# ../lich/super/Physcia_biziana/TSB008265.jpg
# (500, 500, 3)
# ../lich/super/Physcia_biziana/TSB003745.jpg
# (500, 500, 3)
# ../lich/super/Physcia_biziana/TSB000088.jpg
# (500, 500, 3)
# ../lich/super/Physcia_biziana/TSB003713.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_argentata/TSB004699.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_argentata/TSB008930.jpg
# (500, 500, 3)
# ../lich/super/Rinodina_sophodes/TSB001257.jpg
# (500, 500, 3)
# ../lich/super/Rinodina_sophodes/TSB001256.jpg
# (500, 500, 3)
# ../lich/super/Rinodina_sophodes/TSB007665.jpg
# (500, 500, 3)
# ../lich/super/Hyperphyscia_adglutinata/TSB003747.jpg
# (500, 500, 3)
# ../lich/super/Hyperphyscia_adglutinata/TSB003748.jpg
# (500, 500, 3)
# ../lich/super/Punctelia_borreri/TSB010908.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_chlarotera/TSB008755.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_chlarotera/TSB003728.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_chlarotera/TSB014043.jpg
# (500, 500, 3)
# ../lich/super/Phlyctis_argena/TSB008413.jpg
# (500, 500, 3)
# ../lich/super/Phlyctis_argena/TSB008415.jpg
# (500, 500, 3)
# ../lich/super/Phlyctis_argena/TSB003412.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005792.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005793.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005046.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005045.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB004587.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005048.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005658.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB000043.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB000042.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB004597.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB004724.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/XanthoriaparietinaLThFr1544185942.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB003689.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005007.jpg
# (500, 500, 3)
# ../lich/super/Xanthoria_parietina/TSB005990.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB007805.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB001164.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB004154.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB008542.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB004150.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB013996.jpg
# (500, 500, 3)
# ../lich/super/Lecanora_carpinea/TSB004151.jpg
# (500, 500, 3)
# ../lich/super/Physcia_tenella/TSB004626.jpg
# (500, 500, 3)
# ../lich/super/Physcia_tenella/TSB004609.jpg
# (500, 500, 3)
# ../lich/super/Physcia_tenella/TSB004999.jpg
# (500, 500, 3)
# ../lich/super/Physcia_tenella/TSB004939.jpg
# (500, 500, 3)
# ../lich/super/Caloplaca_cerina/TSB011186.jpg
# (500, 500, 3)
# ../lich/super/Caloplaca_cerina/TSB001107.jpg
# (500, 500, 3)
# CPU times: user 1min 57s, sys: 3.36 s, total: 2min 1s
# Wall time: 2min

# %% [markdown]
# # TRAINING

# %%
# %%time
model = Protonet.load_protonet_conv(x_dim=(3,500,500),hid_dim=64,z_dim=64)
optimizer = optim.Adam(model.parameters(), lr = 0.001)
n_way = 3
n_support = 2
n_query = 2

train_x = trainx
train_y = trainy

max_epoch = 5
epoch_size = 100

train_and_test.train(model, optimizer, train_x, train_y, n_way, n_support, n_query, max_epoch, epoch_size)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1 -- Loss: 1703.9112 Acc: 0.7300
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 2 -- Loss: 530.3544 Acc: 0.7100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 3 -- Loss: 396.5706 Acc: 0.7383
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 4 -- Loss: 332.2687 Acc: 0.7283
# Epoch 5 -- Loss: 300.3188 Acc: 0.7283
# CPU times: user 1h 32min 1s, sys: 29min 17s, total: 2h 1min 19s
# Wall time: 2h 1min 18s
# /anaconda3/lib/python3.7/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Protonet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /anaconda3/lib/python3.7/site-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # TESTING

# %%
n_way = 3
n_support = 4
n_query = 4
test_x = testx
test_y = testy
test_episode = 100
train_and_test.test(model, test_x, test_y, n_way, n_support, n_query, test_episode)

# %% [markdown]
# # TEST ON SPECIFIC DATA

# %%
test_x = testx
test_y = testy
n_way = 3
n_support = 4
n_query = 4
my_sample = data.extract_sample(n_way, n_support, n_query, test_x, test_y)
data.display_sample(my_sample['images'])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# %%time
my_loss, my_output = model.set_forward_loss(my_sample)
# Out:
# CPU times: user 11.3 s, sys: 8.25 s, total: 19.5 s
# Wall time: 23.8 s

# %%
my_output
# Out:
# {'loss': 345.3405456542969,
#  'acc': 0.5833333134651184,
#  'y_hat': tensor([[1, 0, 2, 1],
#          [1, 1, 2, 2],
#          [2, 2, 2, 2]])}

# %%
import torch
model = torch.load("model/protonet.pt")
# Out:
# Protonet(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (4): Flatten()
#   )
# )
